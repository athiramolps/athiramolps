# %% [markdown]
# <a href="https://colab.research.google.com/github/athiramolps/athiramolps/blob/main/PART_1_IMPORTING_LIBRARIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import plotly.express as px

# %% [markdown]
# # **LOADING DATASET**

# %%
data1=pd.read_csv('/content/sample_data/GITHHUB/dataset1.csv')
data2=pd.read_csv('/content/sample_data/GITHHUB/dataset2.csv')

# %%
data1
# Out:
#            HOTEL NAME  YEAR OF SALES        OWNER HOTEL LOCATION  LATTITUDE  \
# 0         LOWRY HOTEL           2021  ROSE KELLER           HULL  53.767750
# 1        GORING HOTEL           2021       MATHEW     MANCHESTER  53.483959
# 2       HOTEL RUSSELL           2021          JOY          DERBY  52.916668
# 3       CARLTON HOTEL           2021       ROSHAN      LEICESTER  52.633331
# 4          BLUE MOUNT           2021    ALEXANDER        GLASGOW  55.860916
# 5      FEATHERS HOTEL           2021  CHRISTOPHER      NEWCASTLE  54.966667
# 6          EDEN HOTEL           2021     ANGELINA         DURHAM  54.776100
# 7       CAPITAL HOTEL           2021    FERNANDES      LIVERPOOL  53.400002
# 8         ROYAL HOTEL           2021       GEORGE          PERTH  56.396999
# 9        PALACE HOTEL           2021      WILLSON           BATH  51.380001
# 10     THE BULL HOTEL           2021        RAYAN       COVENTRY  52.408054
# ...

# %%
data2
# Out:
#     TAX TO GOVERNMENT  HOTEL BUILT YEAR
# 0            -3744000              1900
# 1            -2731200              2000
# 2            -3091200              1893
# 3            -1185600              1992
# 4            -1765584              2001
# 5            -1179264              1800
# 6            -3091968              2008
# 7            -2707584              1825
# 8            -2712960              2017
# 9            -4271904              2019
# 10           -3253536              2007
# 11           -1705680              2002
# 12           -4207680              1899
# 13           -2621376              1850
# 14           -2786496              1923
# 15           -3715200              1995
# 16           -4380288              2009
# 17           -4574976              2010
# 18           -3080448              2015

# %% [markdown]
# # **COMBINING DATASET**

# %%
pd.merge(data1,data2,how='left')
# Out:
#            HOTEL NAME  YEAR OF SALES        OWNER HOTEL LOCATION  LATTITUDE  \
# 0         LOWRY HOTEL           2021  ROSE KELLER           HULL  53.767750
# 1        GORING HOTEL           2021       MATHEW     MANCHESTER  53.483959
# 2       HOTEL RUSSELL           2021          JOY          DERBY  52.916668
# 3       CARLTON HOTEL           2021       ROSHAN      LEICESTER  52.633331
# 4          BLUE MOUNT           2021    ALEXANDER        GLASGOW  55.860916
# 5      FEATHERS HOTEL           2021  CHRISTOPHER      NEWCASTLE  54.966667
# 6          EDEN HOTEL           2021     ANGELINA         DURHAM  54.776100
# 7       CAPITAL HOTEL           2021    FERNANDES      LIVERPOOL  53.400002
# 8         ROYAL HOTEL           2021       GEORGE          PERTH  56.396999
# 9        PALACE HOTEL           2021      WILLSON           BATH  51.380001
# 10     THE BULL HOTEL           2021        RAYAN       COVENTRY  52.408054
# ...
